# %% [markdown]
# # <font color='red'>SEDES - Gerador de Dados</font>

# %% [markdown]
# # <font color='blue'>1.0 import</font>

# %%
import csv
import os
import pandas as pd
import random as rd
import datetime as dt
import names
from dateutil.relativedelta import relativedelta

# %% [markdown]
# # <font color='blue'>2.0 parâmetros de ambiente</font>

# %%
# campo de negócio no BI
ORGAO_GESTOR = 'orgaoGestorDaPoliticaDeAssistenciaSocial'
ORGANIZACAO_PPA = 'comoEstaOrganizadoOPPADaPASNoMunicipio'
TUP_INSTR_GESTAO = (
    'planoDecenalDeAssistenciaSocial-possui',
    'planoMunicipalDeAssistenciaSocial-possui',
    'PlanoMunicipaldeEducacaoPermanentedoSUAS-possui',
    'diagnosticoSocioterritorial-possui',
    'RelatoriodeGestaoDoExercicioAnterior-possui',
    'LeideRegulamentacaodoSUAS-possui'
)
AREAS_ESSENCIAIS = (
    'quaisAreasEssenciaisDoSUASEstaoImplantadosOficialmente-gestao_do_trabalho',
    'quaisAreasEssenciaisDoSUASEstaoImplantadosOficialmente-protecao_social_basica',
    'quaisAreasEssenciaisDoSUASEstaoImplantadosOficialmente-protecao_social_especial',
    'quaisAreasEssenciaisDoSUASEstaoImplantadosOficialmente-gestao_do_suas'
)
VS = (
    'oMunicipioDesenvolveQuaisAcoesDeVigilanciaSocioassistencial-levanta_dados_no_territorio_equipamento_da_pas',
    'oMunicipioDesenvolveQuaisAcoesDeVigilanciaSocioassistencial-analisa_dados_levantados',
    'oMunicipioDesenvolveQuaisAcoesDeVigilanciaSocioassistencial-sistematiza_dados_e_produz_relatorios',
    'oMunicipioDesenvolveQuaisAcoesDeVigilanciaSocioassistencial-dissemina_dados_e_ou_relatorios',
    'oMunicipioDesenvolveQuaisAcoesDeVigilanciaSocioassistencial-realiza_diagnostico_socioterritorial',
    'oMunicipioDesenvolveQuaisAcoesDeVigilanciaSocioassistencial-realiza_monitoramento_sistematico_dos_servicos_socioassistenciais',
    'oMunicipioDesenvolveQuaisAcoesDeVigilanciaSocioassistencial-realiza_reunioes_com_as_equipes_responsaveis_pela_execucao_dos_servicos_socioassistenciais'
)
MONITORA_SISTEMAS = (
    'quemAlimentaOsDadosNosSistemasDaRedeSUAS-CAD_SUAS',
    'quemAlimentaOsDadosNosSistemasDaRedeSUAS-RMA',
    'quemAlimentaOsDadosNosSistemasDaRedeSUAS-SISC',
    'quemAlimentaOsDadosNosSistemasDaRedeSUAS-E-PCF',
    'quemAlimentaOsDadosNosSistemasDaRedeSUAS-SIMPETI',
    'quemAlimentaOsDadosNosSistemasDaRedeSUAS-Plano_de_Acao_SAA',
    'quemAlimentaOsDadosNosSistemasDaRedeSUAS-Demonstrativo_Sintetico_de_Execucao_Fisico_Financeiro',
    'quemAlimentaOsDadosNosSistemasDaRedeSUAS-Alimentacao_da_Plataforma_Estadual_de_Monitoramento_da_PAS'
)
ALIMENTA_SUAS = (
    'quemAlimentaOsDadosNosSistemasDaRedeSUAS-gestao',
    'quemAlimentaOsDadosNosSistemasDaRedeSUAS-protecao_social_basica',
    'quemAlimentaOsDadosNosSistemasDaRedeSUAS-protecao_social_especial',
    'quemAlimentaOsDadosNosSistemasDaRedeSUAS-protecao_social_outros'
)
EQUIPE_VS = (
    {'prefixo': 'qualEquipeCompoeOSetorDaVigilanciaSocioassistencial', 'suf_nome': 'nome'},
    {'prefixo': 'qualEquipeCompoeOSetorDaVigilanciaSocioassistencial', 'suf_escolaridade': 'escolaridade'},
    {'prefixo': 'qualEquipeCompoeOSetorDaVigilanciaSocioassistencial', 'suf_formacao': 'formacao'},
    {'prefixo': 'qualEquipeCompoeOSetorDaVigilanciaSocioassistencial', 'suf_cargo': 'cargo'}
)

# data inicial de simulação
DATA_INICIAL = (2018, 3, 1)

# tabelas gerais
N_ORGAO_GESTOR = (6, 11) # quantidade de orgãos gestores possíveis para a tabela de orgãos gestores
N_ESCOLARIDADE = (5, 10) # quantidade de escolaridades possíveis para a tabela escolaridade
N_FORMACAO     = (5, 10) # quantidade de formações possíveis para a tabela formacao
N_CARGO        = (5, 10) # quantidade de cargos possíveis para a tabela cargo
N_EQUIPE_VS    = (2, 6)  # quantidade de pessoas possíveis para compor a equipe de VS
N_CAPACITACOES_OFERTADAS = (0, 100) # quantidade possível de capacitações

# formulários respondidos
form_resp = (80, 100) # % de formulários respondidos
orgao_gestor = (1, 3) # possibilidades de orgão gestor por município a cada data de referência
campos_por_form = (50, 150) # quantidade de campos por formulário sem contar os identificados para o BI

rd.seed(55) # mantem sempre os mesmos parâmetros de randomização

# %%
CAPACITACOES_OFERTADAS = (
    'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeEstado',
    'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeGovernoFederal',
    'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeMunicipio',
    'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
    'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
    'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#     'capacitacoesOfertadasGestaoSUAS-nome',
#     'capacitacoesOfertadasGestaoSUAS-quantidadeEstado',
#     'capacitacoesOfertadasGestaoSUAS-quantidadeGovernoFederal',
#     'capacitacoesOfertadasGestaoSUAS-quantidadeMunicipio',
    'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
    'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
    'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
    'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
    'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
    'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
    'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
    'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
    'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
    'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
    'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
    'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#     'capacitacoesOfertadasProtecaoSocialBasica-nome',
#     'capacitacoesOfertadasProtecaoSocialBasica-quantidadeEstado',
#     'capacitacoesOfertadasProtecaoSocialBasica-quantidadeGovernoFederal',
#     'capacitacoesOfertadasProtecaoSocialBasica-quantidadeMunicipio',
    'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
    'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
    'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeMunicipio',
    'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeEstado',
    'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
    'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
    'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeEstado',
    'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeGovernoFederal',
    'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeMunicipio',
    'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeEstado',
    'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeGovernoFederal',
    'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeMunicipio',
#     'capacitacoesOfertadasProtecaoSocialControleSocial-nome',
#     'capacitacoesOfertadasProtecaoSocialControleSocial-quantidadeEstado',
#     'capacitacoesOfertadasProtecaoSocialControleSocial-quantidadeGovernoFederal',
#     'capacitacoesOfertadasProtecaoSocialControleSocial-quantidadeMunicipio',
    'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeEstado',
    'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
    'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
    'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeEstado',
    'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
    'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
    'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeEstado',
    'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeGovernoFederal',
    'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeMunicipio',
    'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeEstado',
    'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeGovernoFederal',
    'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeMunicipio',
#     'capacitacoesOfertadasProtecaoSocialEspecial-nome',
#     'capacitacoesOfertadasProtecaoSocialEspecial-quantidadeEstado',
#     'capacitacoesOfertadasProtecaoSocialEspecial-quantidadeGovernoFederal',
#     'capacitacoesOfertadasProtecaoSocialEspecial-quantidadeMunicipio',
    'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeEstado',
    'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
    'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
    'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeEstado',
    'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
    'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeMunicipio'
)
len(CAPACITACOES_OFERTADAS)
# Out:
# 48

# %% [markdown]
# # <font color='blue'>3.0 extração</font>

# %% [markdown]
# ## 3.1 extração de dados externo

# %%
# abrindo os arquivos...
caminho_in = '../dados/apoio/'
caminho_out = '../dados/simulacao/'

arq_municipios    = caminho_in + "tab_municipios_new.csv"
arq_instr_gestao  = caminho_in + "tab_instr_gestao.csv"
arq_escolaridades = caminho_in + "tab_escolaridade.csv"
arq_formacoes     = caminho_in + "tab_formacoes.csv"
arq_cargos        = caminho_in + "tab_cargos.csv"

with open(arq_escolaridades) as f:
    lst_tot_escolaridades = list(csv.reader(f))
    
with open(arq_formacoes) as f:
    lst_tot_formacoes = list(csv.reader(f))
    
with open(arq_cargos) as f:
    lst_tot_cargos = list(csv.reader(f))

df_municipios =   pd.read_csv(arq_municipios, sep = ',', dtype = str)
df_instr_gestao = pd.read_csv(arq_instr_gestao, sep = ',', dtype = str)

print("municipios:              linhas = %s , colunas = %s " % df_municipios.shape)
print("instrumentos de gestão:  linhas = %s , colunas = %s " % df_instr_gestao.shape)
print("escolaridades:           linhas = %s " % len(lst_tot_escolaridades))
print("formacoes:               linhas = %s " % len(lst_tot_formacoes))
print("cargos:                  linhas = %s " % len(lst_tot_cargos))
# Out:
# municipios:              linhas = 217 , colunas = 4
# instrumentos de gestão:  linhas = 5 , colunas = 1
# escolaridades:           linhas = 13
# formacoes:               linhas = 226
# cargos:                  linhas = 134

# %%
df_municipios
# Out:
#     cod_ibge                municipio                     regiao_planejamento  \
# 0    2100055               Açailândia                 24 – REGIÃO DOS CARAJÁS
# 1    2100105             Afonso Cunha               07 – REGIÃO DO ALTO MUNIM
# 2    2100154    Água Doce Do Maranhão        13 – REGIÃO DO DELTA DO PARNAÍBA
# 3    2100204                Alcântara                 20 – REGIÃO DO PERICUMÃ
# 4    2100303            Aldeias Altas                32 – REGIÃO DOS TIMBIRAS
# ..       ...                      ...                                     ...
# 212  2112803                    Viana                   30 – REGIÃO DOS LAGOS
# 213  2112852  Vila Nova Dos Martírios                 24 – REGIÃO DOS CARAJÁS
# 214  2112902        Vitória Do Mearim  26 – REGIÃO DOS EIXOS RODOFERROVIÁRIOS
# 215  2113009          Vitorino Freire                   17 – REGIÃO DO MEARIM
# 216  2114007                  Zé Doca                08 – REGIÃO DO ALTO TURI
#
#             porte
# 0    Grande Porte
# 1         Porte I
# 2         Porte I
# 3        Porte II
# 4        Porte II
# ..            ...
# 212      Porte II
# 213       Porte I
# 214      Porte II
# 215      Porte II
# 216   Médio Porte
#
# [217 rows x 4 columns]

# %% [markdown]
# # <font color='blue'>4.0 transformação</font>

# %% [markdown]
# ## 4.1 Tabelas de Negócio

# %% [markdown]
# ### 4.1.1 tabela de "Orgãos Gestores"

# %%
# cria uma tabela de orgãos gestores possíveis
# quantidade de orgão gestores na tabela

lst_OG = ['Orgão Gestor ' + str(x + 1).zfill(2) for x in range(rd.randint(N_ORGAO_GESTOR[0], N_ORGAO_GESTOR[1]))]
lst_OG
# Out:
# ['Orgão Gestor 01',
#  'Orgão Gestor 02',
#  'Orgão Gestor 03',
#  'Orgão Gestor 04',
#  'Orgão Gestor 05',
#  'Orgão Gestor 06']

# %% [markdown]
# ### 4.1.2 tabela de "Organização de PPAs"

# %%
lst_org_PPA = (
    'Por nível de proteção social',
    'Por programas, serviços, projetos e benefícios'
)
lst_org_PPA
# Out:
# ('Por nível de proteção social',
#  'Por programas, serviços, projetos e benefícios')

# %% [markdown]
# ### 4.1.3 tabela de "Escolaridade"

# %%
# sorteia a quantidade de nomes de escolaridades irão para a lista
n = rd.randint(N_ESCOLARIDADE[0], N_ESCOLARIDADE[1])

# sorteia quais os nomes de escolaridade farão parte dos dados
lst_escolaridade = rd.sample(lst_tot_escolaridades, k=n)
lst_escolaridade
# Out:
# [['Fundamental - Completo'],
#  ['Pós-graduação (nível doutor) - Incompleto'],
#  ['Médio - Completo'],
#  ['Fundamental - Incompleto'],
#  ['Pós-graduação (nível doutor) - Completo'],
#  ['Pós-graduação (nível mestrado) - Completo']]

# %% [markdown]
# ### 4.1.4 tabela de "Formação"

# %%
# sorteia a quantidade de nomes de formações irão para a lista
n = rd.randint(N_FORMACAO[0], N_FORMACAO[1])

# sorteia quais os nomes de escolaridade farão parte dos dados
lst_formacao = rd.sample(lst_tot_formacoes, k=n)
lst_formacao
# Out:
# [['Cooperativismo'],
#  ['Materiais'],
#  ['Psicologia'],
#  ['Engenharia Industrial Madeireira'],
#  ['Jornalismo']]

# %% [markdown]
# ### 4.1.5 tabela de "Cargo"

# %%
# sorteia a quantidade de nomes de cargos irão para a lista
n = rd.randint(N_CARGO[0], N_CARGO[1])

# sorteia quais os nomes de escolaridade farão parte dos dados
lst_cargo = rd.sample(lst_tot_cargos, k=n)
lst_cargo
# Out:
# [['Tecnico em Radiologia '],
#  ['Servicos Gerais '],
#  ['Mecanico '],
#  ['Especialistas '],
#  ['Sargento '],
#  ['Bibliotecário '],
#  ['Gerente '],
#  ['Controlador '],
#  ['Atendente de caixa ']]

# %% [markdown]
# ### 4.1.6 tabela "Município"

# %%
df_municipios = df_municipios[['municipio']]
df_municipios
# Out:
#                    municipio
# 0                 Açailândia
# 1               Afonso Cunha
# 2      Água Doce Do Maranhão
# 3                  Alcântara
# 4              Aldeias Altas
# ..                       ...
# 212                    Viana
# 213  Vila Nova Dos Martírios
# 214        Vitória Do Mearim
# 215          Vitorino Freire
# 216                  Zé Doca
#
# [217 rows x 1 columns]

# %% [markdown]
# ### 4.1.7 tabela "Serviço/Formulário"

# %%
# lista de serviços (cada serviço é equivalente e um formulário)
tup_servicos = (
    ('o1-semestral municipio', 'semestral', 'municipios'),
    ('o1-semestral SEDES',     'semestral', 'sedes')
)
df_tb_servicos = pd.DataFrame(tup_servicos, columns=['servico', 'periodicidade', 'alvo'])
df_tb_servicos
# Out:
#                   servico periodicidade        alvo
# 0  o1-semestral municipio     semestral  municipios
# 1      o1-semestral SEDES     semestral       sedes

# %% [markdown]
# ### 4.1.8 serviços/formulário x campos fictícios

# %%
# lista de campos por serviço/formulário
cont = 0; lst_campos = []
for i in tup_servicos:
    n_campos = rd.randint(10, 15)
    for j in range(n_campos):
        cont += 1
        lst = [i[0], 'col_' + str(cont), 'STRING']
        lst_campos.append(lst)
lst_campos

df_campos_fic = pd.DataFrame(lst_campos, columns=['servico', 'atributo', 'tipo'])
df_campos_fic
# Out:
#                    servico atributo    tipo
# 0   o1-semestral municipio    col_1  STRING
# 1   o1-semestral municipio    col_2  STRING
# 2   o1-semestral municipio    col_3  STRING
# 3   o1-semestral municipio    col_4  STRING
# 4   o1-semestral municipio    col_5  STRING
# 5   o1-semestral municipio    col_6  STRING
# 6   o1-semestral municipio    col_7  STRING
# 7   o1-semestral municipio    col_8  STRING
# 8   o1-semestral municipio    col_9  STRING
# 9   o1-semestral municipio   col_10  STRING
# 10  o1-semestral municipio   col_11  STRING
# 11  o1-semestral municipio   col_12  STRING
# 12  o1-semestral municipio   col_13  STRING
# 13  o1-semestral municipio   col_14  STRING
# 14      o1-semestral SEDES   col_15  STRING
# 15      o1-semestral SEDES   col_16  STRING
# 16      o1-semestral SEDES   col_17  STRING
# 17      o1-semestral SEDES   col_18  STRING
# 18      o1-semestral SEDES   col_19  STRING
# 19      o1-semestral SEDES   col_20  STRING
# 20      o1-semestral SEDES   col_21  STRING
# 21      o1-semestral SEDES   col_22  STRING
# 22      o1-semestral SEDES   col_23  STRING
# 23      o1-semestral SEDES   col_24  STRING
# 24      o1-semestral SEDES   col_25  STRING
# 25      o1-semestral SEDES   col_26  STRING
# 26      o1-semestral SEDES   col_27  STRING
# 27      o1-semestral SEDES   col_28  STRING
# 28      o1-semestral SEDES   col_29  STRING

# %% [markdown]
# ## (A) Módulo Semestral

# %% [markdown]
# ### A.1 gera datas base - semestral

# %%
# cria uma coleção de datas de referências de todos os semestres desde o início até hoje
# confirma que a data inicial é o primeiro dia do semestre
dt_inicial = dt.date(DATA_INICIAL[0], 1 if DATA_INICIAL[1] <= 6 else 7, 1)

# monta uma lista de todos os semestres desde a data inicial até hoje
lst_dt_semestral = []; dt_atual = dt_inicial
while dt_atual < dt.date.today():
    dtf = dt_atual + relativedelta(months = 6) - relativedelta(days = 1)
    n_dias = (dtf - dt_atual).days
    lst_dt_semestral.append([dt_atual, dtf, n_dias])
    dt_atual = dt_atual + relativedelta(months = 6)

# substitui a última data pela data de hoje
lst_dt_semestral[len(lst_dt_semestral) - 1][1] = dt.date.today()
lst_dt_semestral[len(lst_dt_semestral) - 1][2] = (lst_dt_semestral[len(lst_dt_semestral) - 1][1] - lst_dt_semestral[len(lst_dt_semestral) - 1][0]).days
lst_dt_semestral
# Out:
# [[datetime.date(2018, 1, 1), datetime.date(2018, 6, 30), 180],
#  [datetime.date(2018, 7, 1), datetime.date(2018, 12, 31), 183],
#  [datetime.date(2019, 1, 1), datetime.date(2019, 6, 30), 180],
#  [datetime.date(2019, 7, 1), datetime.date(2019, 12, 31), 183],
#  [datetime.date(2020, 1, 1), datetime.date(2020, 6, 30), 181],
#  [datetime.date(2020, 7, 1), datetime.date(2020, 12, 31), 183],
#  [datetime.date(2021, 1, 1), datetime.date(2021, 6, 30), 180],
#  [datetime.date(2021, 7, 1), datetime.date(2021, 7, 16), 15]]

# %% [markdown]
# ### A.2 BASE formulários MUNICÍPIOS

# %% [markdown]
# #### A.2.1 Protocolos/Dt_Protocolos/Municípios

# %%
# cria a combinação de municípios e serviços para alvo "municípios"
dfa = df_tb_servicos[df_tb_servicos['alvo'] == 'municipios'][['servico', 'periodicidade']]
df = pd.merge(dfa, df_municipios, how='cross')

# cria datas de protocolos
lst = []; pct = 1
for idx in range(df.shape[0]):
    for i in lst_dt_semestral:
        n_protocolos = rd.randint(0, 3)
        if n_protocolos > 0:
            lst.append([idx, 'pct_m_' + str(pct), i[0],
                        df.loc[idx, 'servico'], df.loc[idx, 'municipio']])
            pct += 1
            for j in range(1, n_protocolos):
                dias = rd.randint(1, i[2])
                dt = i[0] + relativedelta(days = dias)
                lst.append([idx, 'pct_m_' + str(pct), dt, 
                            df.loc[idx, 'servico'], df.loc[idx, 'municipio']])
                pct += 1
df_pct_mu = pd.DataFrame(lst, columns=['idx', 'protocolo', 'dt_protocolo', 'servico', 'municipio'])
lst_pct_mu = list(df_pct_mu['protocolo'])
display(df_pct_mu)
# Out:
#       idx   protocolo dt_protocolo                 servico   municipio
# 0       0     pct_m_1   2018-07-01  o1-semestral municipio  Açailândia
# 1       0     pct_m_2   2018-08-28  o1-semestral municipio  Açailândia
# 2       0     pct_m_3   2018-07-15  o1-semestral municipio  Açailândia
# 3       0     pct_m_4   2019-01-01  o1-semestral municipio  Açailândia
# 4       0     pct_m_5   2019-03-02  o1-semestral municipio  Açailândia
# ...   ...         ...          ...                     ...         ...
# 2660  216  pct_m_2661   2021-01-01  o1-semestral municipio     Zé Doca
# 2661  216  pct_m_2662   2021-06-24  o1-semestral municipio     Zé Doca
# 2662  216  pct_m_2663   2021-07-01  o1-semestral municipio     Zé Doca
# 2663  216  pct_m_2664   2021-07-15  o1-semestral municipio     Zé Doca
# 2664  216  pct_m_2665   2021-07-02  o1-semestral municipio     Zé Doca
#
# [2665 rows x 5 columns]

# %% [markdown]
# #### A.2.2 Campos Fictícios - (A.2.1) x (A.1.8)

# %%
df_final = pd.merge(df_pct_mu, df_campos_fic).drop(['idx', 'municipio'], axis=1)
df_final
# Out:
#         protocolo dt_protocolo                 servico atributo    tipo
# 0         pct_m_1   2018-07-01  o1-semestral municipio    col_1  STRING
# 1         pct_m_1   2018-07-01  o1-semestral municipio    col_2  STRING
# 2         pct_m_1   2018-07-01  o1-semestral municipio    col_3  STRING
# 3         pct_m_1   2018-07-01  o1-semestral municipio    col_4  STRING
# 4         pct_m_1   2018-07-01  o1-semestral municipio    col_5  STRING
# ...           ...          ...                     ...      ...     ...
# 37305  pct_m_2665   2021-07-02  o1-semestral municipio   col_10  STRING
# 37306  pct_m_2665   2021-07-02  o1-semestral municipio   col_11  STRING
# 37307  pct_m_2665   2021-07-02  o1-semestral municipio   col_12  STRING
# 37308  pct_m_2665   2021-07-02  o1-semestral municipio   col_13  STRING
# 37309  pct_m_2665   2021-07-02  o1-semestral municipio   col_14  STRING
#
# [37310 rows x 5 columns]

# %% [markdown]
# #### A.2.3 Atribuição de Valores aos Campos Fictícios - (A.2.2) + coluna "valor"

# %%
def GeraValor(tp):
    vl = '0'
    if tp == 'STRING':
        vl = 'valor_' + str(rd.randint(1, 1000))
    return vl

df_final['valor'] = df_final['tipo'].apply(GeraValor)
df_final
# Out:
#         protocolo dt_protocolo                 servico atributo    tipo  \
# 0         pct_m_1   2018-07-01  o1-semestral municipio    col_1  STRING
# 1         pct_m_1   2018-07-01  o1-semestral municipio    col_2  STRING
# 2         pct_m_1   2018-07-01  o1-semestral municipio    col_3  STRING
# 3         pct_m_1   2018-07-01  o1-semestral municipio    col_4  STRING
# 4         pct_m_1   2018-07-01  o1-semestral municipio    col_5  STRING
# ...           ...          ...                     ...      ...     ...
# 37305  pct_m_2665   2021-07-02  o1-semestral municipio   col_10  STRING
# 37306  pct_m_2665   2021-07-02  o1-semestral municipio   col_11  STRING
# 37307  pct_m_2665   2021-07-02  o1-semestral municipio   col_12  STRING
# 37308  pct_m_2665   2021-07-02  o1-semestral municipio   col_13  STRING
# 37309  pct_m_2665   2021-07-02  o1-semestral municipio   col_14  STRING
#
#            valor
# 0      valor_440
# 1      valor_651
# 2      valor_936
# 3       valor_40
# 4      valor_272
# ...          ...
# 37305  valor_695
# 37306   valor_76
# 37307  valor_167
# 37308  valor_874
# 37309   valor_75
#
# [37310 rows x 6 columns]

# %% [markdown]
# #### A.2.4 Gera linha/campo com atributo "município" e concatena com campos fictícios - (A.2.3)

# %%
# gera um dataset temporário de atributos municípios
df_tmp = df_pct_mu.copy()
df_tmp['atributo'] = 'municipio'
df_tmp['tipo'] = 'STRING'
df_tmp = df_tmp.rename(columns={'municipio': 'valor'})
df_tmp = df_tmp.drop(['idx'], axis=1)

# gera dataset final para aplicar os registros de negócio
df_final = pd.concat([df_final, df_tmp])
df_final
# Out:
#        protocolo dt_protocolo                 servico   atributo    tipo  \
# 0        pct_m_1   2018-07-01  o1-semestral municipio      col_1  STRING
# 1        pct_m_1   2018-07-01  o1-semestral municipio      col_2  STRING
# 2        pct_m_1   2018-07-01  o1-semestral municipio      col_3  STRING
# 3        pct_m_1   2018-07-01  o1-semestral municipio      col_4  STRING
# 4        pct_m_1   2018-07-01  o1-semestral municipio      col_5  STRING
# ...          ...          ...                     ...        ...     ...
# 2660  pct_m_2661   2021-01-01  o1-semestral municipio  municipio  STRING
# 2661  pct_m_2662   2021-06-24  o1-semestral municipio  municipio  STRING
# 2662  pct_m_2663   2021-07-01  o1-semestral municipio  municipio  STRING
# 2663  pct_m_2664   2021-07-15  o1-semestral municipio  municipio  STRING
# 2664  pct_m_2665   2021-07-02  o1-semestral municipio  municipio  STRING
#
#           valor
# 0     valor_440
# 1     valor_651
# 2     valor_936
# 3      valor_40
# 4     valor_272
# ...         ...
# 2660    Zé Doca
# 2661    Zé Doca
# 2662    Zé Doca
# 2663    Zé Doca
# 2664    Zé Doca
#
# [39975 rows x 6 columns]

# %% [markdown]
# ### A.3 BASE formulários SEDES-MA

# %% [markdown]
# #### A.3.1 Protocolos/Dt_Protocolos/Sedes

# %%
# cria a combinação de municípios e serviços para alvo "SEDES"
df = df_tb_servicos[df_tb_servicos['alvo'] == 'sedes'][['servico', 'periodicidade']].reset_index()
df['respondedor'] = 'sedes'

# cria datas de protocolos
lst = []; pct = 1
for idx in range(df.shape[0]):
    for i in lst_dt_semestral:
        n_protocolos = rd.randint(0, 3)
        if n_protocolos > 0:
            lst.append([idx, 'pct_s_' + str(pct), i[0], 
                        df.loc[idx, 'servico'], df.loc[idx, 'respondedor']])
            pct += 1
            for j in range(1, n_protocolos):
                dias = rd.randint(1, i[2])
                dt = i[0] + relativedelta(days = dias)
                lst.append([idx, 'pct_s_' + str(pct), dt, 
                            df.loc[idx, 'servico'], df.loc[idx, 'respondedor']])
                pct += 1
df_pct_se = pd.DataFrame(lst, columns=['idx', 'protocolo', 'dt_protocolo', 'servico', 'respondedor'])
lst_pct_se = list(df_pct_se['protocolo'])
display(df_pct_se)
# Out:
#     idx protocolo dt_protocolo             servico respondedor
# 0     0   pct_s_1   2018-01-01  o1-semestral SEDES       sedes
# 1     0   pct_s_2   2018-07-01  o1-semestral SEDES       sedes
# 2     0   pct_s_3   2018-07-16  o1-semestral SEDES       sedes
# 3     0   pct_s_4   2018-07-06  o1-semestral SEDES       sedes
# 4     0   pct_s_5   2019-01-01  o1-semestral SEDES       sedes
# 5     0   pct_s_6   2019-05-14  o1-semestral SEDES       sedes
# 6     0   pct_s_7   2019-07-01  o1-semestral SEDES       sedes
# 7     0   pct_s_8   2019-09-16  o1-semestral SEDES       sedes
# 8     0   pct_s_9   2020-01-01  o1-semestral SEDES       sedes
# 9     0  pct_s_10   2020-05-26  o1-semestral SEDES       sedes
# 10    0  pct_s_11   2020-07-01  o1-semestral SEDES       sedes
# 11    0  pct_s_12   2020-12-16  o1-semestral SEDES       sedes
# 12    0  pct_s_13   2021-01-01  o1-semestral SEDES       sedes
# 13    0  pct_s_14   2021-07-01  o1-semestral SEDES       sedes
# 14    0  pct_s_15   2021-07-09  o1-semestral SEDES       sedes

# %% [markdown]
# ### A.3 NEGOCIO formulários Municípios

# %% [markdown]
# ### E.1 Orgão Gestor

# %%
# métrica Órgão Gestor
colunas = ['protocolo', 'dt_protocolo', 'servico']
df_tmp = df_pct_mu[(df_pct_mu['servico'] == 'o1-semestral municipio')][colunas]
df_tmp['atributo'] = ORGAO_GESTOR
df_tmp['tipo'] = 'STRING'
df_tmp['valor'] = df_tmp.apply(lambda row: rd.sample(lst_OG, k=1)[0], axis=1)

df_final = pd.concat([df_final, df_tmp])
df_final
# Out:
#        protocolo dt_protocolo                 servico  \
# 0        pct_m_1   2018-07-01  o1-semestral municipio
# 1        pct_m_1   2018-07-01  o1-semestral municipio
# 2        pct_m_1   2018-07-01  o1-semestral municipio
# 3        pct_m_1   2018-07-01  o1-semestral municipio
# 4        pct_m_1   2018-07-01  o1-semestral municipio
# ...          ...          ...                     ...
# 2660  pct_m_2661   2021-01-01  o1-semestral municipio
# 2661  pct_m_2662   2021-06-24  o1-semestral municipio
# 2662  pct_m_2663   2021-07-01  o1-semestral municipio
# 2663  pct_m_2664   2021-07-15  o1-semestral municipio
# 2664  pct_m_2665   2021-07-02  o1-semestral municipio
#
#                                       atributo    tipo            valor
# 0                                        col_1  STRING        valor_440
# 1                                        col_2  STRING        valor_651
# 2                                        col_3  STRING        valor_936
# 3                                        col_4  STRING         valor_40
# 4                                        col_5  STRING        valor_272
# ...                                        ...     ...              ...
# 2660  orgaoGestorDaPoliticaDeAssistenciaSocial  STRING  Orgão Gestor 01
# 2661  orgaoGestorDaPoliticaDeAssistenciaSocial  STRING  Orgão Gestor 05
# 2662  orgaoGestorDaPoliticaDeAssistenciaSocial  STRING  Orgão Gestor 05
# 2663  orgaoGestorDaPoliticaDeAssistenciaSocial  STRING  Orgão Gestor 01
# 2664  orgaoGestorDaPoliticaDeAssistenciaSocial  STRING  Orgão Gestor 05
#
# [42640 rows x 6 columns]

# %% [markdown]
# ### E.2 Instrumentos de Gestão

# %%
# métrica Órgão Gestor
lst_vls = ('false', 'true')
colunas = ['protocolo', 'dt_protocolo', 'servico']

for i in TUP_INSTR_GESTAO:
    df_tmp = df_pct_mu[(df_pct_mu['servico'] == 'o1-semestral municipio')][colunas]
    df_tmp['atributo'] = i
    df_tmp['tipo'] = 'STRING'
    df_tmp['valor'] = df_tmp.apply(lambda row: rd.sample(lst_vls, k=1)[0], axis=1)
    df_tmp = pd.concat([df_final, df_tmp])

df_final
# Out:
#        protocolo dt_protocolo                 servico  \
# 0        pct_m_1   2018-07-01  o1-semestral municipio
# 1        pct_m_1   2018-07-01  o1-semestral municipio
# 2        pct_m_1   2018-07-01  o1-semestral municipio
# 3        pct_m_1   2018-07-01  o1-semestral municipio
# 4        pct_m_1   2018-07-01  o1-semestral municipio
# ...          ...          ...                     ...
# 2660  pct_m_2661   2021-01-01  o1-semestral municipio
# 2661  pct_m_2662   2021-06-24  o1-semestral municipio
# 2662  pct_m_2663   2021-07-01  o1-semestral municipio
# 2663  pct_m_2664   2021-07-15  o1-semestral municipio
# 2664  pct_m_2665   2021-07-02  o1-semestral municipio
#
#                                       atributo    tipo            valor
# 0                                        col_1  STRING        valor_440
# 1                                        col_2  STRING        valor_651
# 2                                        col_3  STRING        valor_936
# 3                                        col_4  STRING         valor_40
# 4                                        col_5  STRING        valor_272
# ...                                        ...     ...              ...
# 2660  orgaoGestorDaPoliticaDeAssistenciaSocial  STRING  Orgão Gestor 01
# 2661  orgaoGestorDaPoliticaDeAssistenciaSocial  STRING  Orgão Gestor 05
# 2662  orgaoGestorDaPoliticaDeAssistenciaSocial  STRING  Orgão Gestor 05
# 2663  orgaoGestorDaPoliticaDeAssistenciaSocial  STRING  Orgão Gestor 01
# 2664  orgaoGestorDaPoliticaDeAssistenciaSocial  STRING  Orgão Gestor 05
#
# [42640 rows x 6 columns]

# %% [markdown]
# ### E.3 Áreas Essenciais

# %%
# métrica Áreas Essenciais
lst_vls = ('false', 'true')
colunas = ['protocolo', 'dt_protocolo', 'servico']

for i in AREAS_ESSENCIAIS:
    df_tmp = df_pct_mu[(df_pct_mu['servico'] == 'o1-semestral municipio')][colunas]
    df_tmp['atributo'] = i
    df_tmp['tipo'] = 'STRING'
    df_tmp['valor'] = df_tmp.apply(lambda row: rd.sample(lst_vls, k=1)[0], axis=1)
    df_final = pd.concat([df_final, df_tmp])

df_final
# Out:
#        protocolo dt_protocolo                 servico  \
# 0        pct_m_1   2018-07-01  o1-semestral municipio
# 1        pct_m_1   2018-07-01  o1-semestral municipio
# 2        pct_m_1   2018-07-01  o1-semestral municipio
# 3        pct_m_1   2018-07-01  o1-semestral municipio
# 4        pct_m_1   2018-07-01  o1-semestral municipio
# ...          ...          ...                     ...
# 2660  pct_m_2661   2021-01-01  o1-semestral municipio
# 2661  pct_m_2662   2021-06-24  o1-semestral municipio
# 2662  pct_m_2663   2021-07-01  o1-semestral municipio
# 2663  pct_m_2664   2021-07-15  o1-semestral municipio
# 2664  pct_m_2665   2021-07-02  o1-semestral municipio
#
#                                                atributo    tipo      valor
# 0                                                 col_1  STRING  valor_440
# 1                                                 col_2  STRING  valor_651
# 2                                                 col_3  STRING  valor_936
# 3                                                 col_4  STRING   valor_40
# 4                                                 col_5  STRING  valor_272
# ...                                                 ...     ...        ...
# 2660  quaisAreasEssenciaisDoSUASEstaoImplantadosOfic...  STRING       true
# 2661  quaisAreasEssenciaisDoSUASEstaoImplantadosOfic...  STRING      false
# 2662  quaisAreasEssenciaisDoSUASEstaoImplantadosOfic...  STRING       true
# 2663  quaisAreasEssenciaisDoSUASEstaoImplantadosOfic...  STRING      false
# 2664  quaisAreasEssenciaisDoSUASEstaoImplantadosOfic...  STRING       true
#
# [53300 rows x 6 columns]

# %% [markdown]
# ### E.4 Organização PPA

# %%
# métrica Organização de PPA no município
colunas = ['protocolo', 'dt_protocolo', 'servico']
df_tmp = df_pct_mu[(df_pct_mu['servico'] == 'o1-semestral municipio')][colunas]
df_tmp['atributo'] = ORGANIZACAO_PPA
df_tmp['tipo'] = 'STRING'
df_tmp['valor'] = df_tmp.apply(lambda row: rd.sample(lst_org_PPA, k=1)[0], axis=1)

df_final = pd.concat([df_final, df_tmp])
df_final
# Out:
#        protocolo dt_protocolo                 servico  \
# 0        pct_m_1   2018-07-01  o1-semestral municipio
# 1        pct_m_1   2018-07-01  o1-semestral municipio
# 2        pct_m_1   2018-07-01  o1-semestral municipio
# 3        pct_m_1   2018-07-01  o1-semestral municipio
# 4        pct_m_1   2018-07-01  o1-semestral municipio
# ...          ...          ...                     ...
# 2660  pct_m_2661   2021-01-01  o1-semestral municipio
# 2661  pct_m_2662   2021-06-24  o1-semestral municipio
# 2662  pct_m_2663   2021-07-01  o1-semestral municipio
# 2663  pct_m_2664   2021-07-15  o1-semestral municipio
# 2664  pct_m_2665   2021-07-02  o1-semestral municipio
#
#                                     atributo    tipo  \
# 0                                      col_1  STRING
# 1                                      col_2  STRING
# 2                                      col_3  STRING
# 3                                      col_4  STRING
# 4                                      col_5  STRING
# ...                                      ...     ...
# 2660  comoEstaOrganizadoOPPADaPASNoMunicipio  STRING
# 2661  comoEstaOrganizadoOPPADaPASNoMunicipio  STRING
# 2662  comoEstaOrganizadoOPPADaPASNoMunicipio  STRING
# 2663  comoEstaOrganizadoOPPADaPASNoMunicipio  STRING
# 2664  comoEstaOrganizadoOPPADaPASNoMunicipio  STRING
#
#                                                valor
# 0                                          valor_440
# 1                                          valor_651
# 2                                          valor_936
# 3                                           valor_40
# 4                                          valor_272
# ...                                              ...
# 2660  Por programas, serviços, projetos e benefícios
# 2661                    Por nível de proteção social
# 2662  Por programas, serviços, projetos e benefícios
# 2663  Por programas, serviços, projetos e benefícios
# 2664                    Por nível de proteção social
#
# [55965 rows x 6 columns]

# %% [markdown]
# ### E.5 Vigilância Socioassistencial - VS

# %%
# métrica Vigilância SocioAssistencial
lst_vls = ('false', 'true')
colunas = ['protocolo', 'dt_protocolo', 'servico']

for i in VS:
    df_tmp = df_pct_mu[(df_pct_mu['servico'] == 'o1-semestral municipio')][colunas]
    df_tmp['atributo'] = i
    df_tmp['tipo'] = 'STRING'
    df_tmp['valor'] = df_tmp.apply(lambda row: rd.sample(lst_vls, k=1)[0], axis=1)
    df_final = pd.concat([df_final, df_tmp])

df_final
# Out:
#        protocolo dt_protocolo                 servico  \
# 0        pct_m_1   2018-07-01  o1-semestral municipio
# 1        pct_m_1   2018-07-01  o1-semestral municipio
# 2        pct_m_1   2018-07-01  o1-semestral municipio
# 3        pct_m_1   2018-07-01  o1-semestral municipio
# 4        pct_m_1   2018-07-01  o1-semestral municipio
# ...          ...          ...                     ...
# 2660  pct_m_2661   2021-01-01  o1-semestral municipio
# 2661  pct_m_2662   2021-06-24  o1-semestral municipio
# 2662  pct_m_2663   2021-07-01  o1-semestral municipio
# 2663  pct_m_2664   2021-07-15  o1-semestral municipio
# 2664  pct_m_2665   2021-07-02  o1-semestral municipio
#
#                                                atributo    tipo      valor
# 0                                                 col_1  STRING  valor_440
# 1                                                 col_2  STRING  valor_651
# 2                                                 col_3  STRING  valor_936
# 3                                                 col_4  STRING   valor_40
# 4                                                 col_5  STRING  valor_272
# ...                                                 ...     ...        ...
# 2660  oMunicipioDesenvolveQuaisAcoesDeVigilanciaSoci...  STRING       true
# 2661  oMunicipioDesenvolveQuaisAcoesDeVigilanciaSoci...  STRING       true
# 2662  oMunicipioDesenvolveQuaisAcoesDeVigilanciaSoci...  STRING      false
# 2663  oMunicipioDesenvolveQuaisAcoesDeVigilanciaSoci...  STRING      false
# 2664  oMunicipioDesenvolveQuaisAcoesDeVigilanciaSoci...  STRING      false
#
# [74620 rows x 6 columns]

# %% [markdown]
# ### E.6 Monitoramento da Alimentação de Dados da Rede SUAS

# %%
# Monitoramento de Sistemas
lst_vls = ('false', 'true')
colunas = ['protocolo', 'dt_protocolo', 'servico']

for i in MONITORA_SISTEMAS:
    df_tmp = df_pct_mu[(df_pct_mu['servico'] == 'o1-semestral municipio')][colunas]
    df_tmp['atributo'] = i
    df_tmp['tipo'] = 'STRING'
    df_tmp['valor'] = df_tmp.apply(lambda row: rd.sample(lst_vls, k=1)[0], axis=1)
    df_final = pd.concat([df_final, df_tmp])

df_final
# Out:
#        protocolo dt_protocolo                 servico  \
# 0        pct_m_1   2018-07-01  o1-semestral municipio
# 1        pct_m_1   2018-07-01  o1-semestral municipio
# 2        pct_m_1   2018-07-01  o1-semestral municipio
# 3        pct_m_1   2018-07-01  o1-semestral municipio
# 4        pct_m_1   2018-07-01  o1-semestral municipio
# ...          ...          ...                     ...
# 2660  pct_m_2661   2021-01-01  o1-semestral municipio
# 2661  pct_m_2662   2021-06-24  o1-semestral municipio
# 2662  pct_m_2663   2021-07-01  o1-semestral municipio
# 2663  pct_m_2664   2021-07-15  o1-semestral municipio
# 2664  pct_m_2665   2021-07-02  o1-semestral municipio
#
#                                                atributo    tipo      valor
# 0                                                 col_1  STRING  valor_440
# 1                                                 col_2  STRING  valor_651
# 2                                                 col_3  STRING  valor_936
# 3                                                 col_4  STRING   valor_40
# 4                                                 col_5  STRING  valor_272
# ...                                                 ...     ...        ...
# 2660  quemAlimentaOsDadosNosSistemasDaRedeSUAS-Alime...  STRING       true
# 2661  quemAlimentaOsDadosNosSistemasDaRedeSUAS-Alime...  STRING       true
# 2662  quemAlimentaOsDadosNosSistemasDaRedeSUAS-Alime...  STRING       true
# 2663  quemAlimentaOsDadosNosSistemasDaRedeSUAS-Alime...  STRING      false
# 2664  quemAlimentaOsDadosNosSistemasDaRedeSUAS-Alime...  STRING      false
#
# [95940 rows x 6 columns]

# %% [markdown]
# ### E.7 Alimentação de Dados da Rede SUAS

# %%
# Alimentação de Dados no sistema da Rede SUAS
lst_vls = ('false', 'true')
colunas = ['protocolo', 'dt_protocolo', 'servico']

for i in ALIMENTA_SUAS:
    df_tmp = df_pct_mu[(df_pct_mu['servico'] == 'o1-semestral municipio')][colunas]
    df_tmp['atributo'] = i
    df_tmp['tipo'] = 'STRING'
    df_tmp['valor'] = df_tmp.apply(lambda row: rd.sample(lst_vls, k=1)[0], axis=1)
    df_final = pd.concat([df_final, df_tmp])

df_final
# Out:
#        protocolo dt_protocolo                 servico  \
# 0        pct_m_1   2018-07-01  o1-semestral municipio
# 1        pct_m_1   2018-07-01  o1-semestral municipio
# 2        pct_m_1   2018-07-01  o1-semestral municipio
# 3        pct_m_1   2018-07-01  o1-semestral municipio
# 4        pct_m_1   2018-07-01  o1-semestral municipio
# ...          ...          ...                     ...
# 2660  pct_m_2661   2021-01-01  o1-semestral municipio
# 2661  pct_m_2662   2021-06-24  o1-semestral municipio
# 2662  pct_m_2663   2021-07-01  o1-semestral municipio
# 2663  pct_m_2664   2021-07-15  o1-semestral municipio
# 2664  pct_m_2665   2021-07-02  o1-semestral municipio
#
#                                                atributo    tipo      valor
# 0                                                 col_1  STRING  valor_440
# 1                                                 col_2  STRING  valor_651
# 2                                                 col_3  STRING  valor_936
# 3                                                 col_4  STRING   valor_40
# 4                                                 col_5  STRING  valor_272
# ...                                                 ...     ...        ...
# 2660  quemAlimentaOsDadosNosSistemasDaRedeSUAS-prote...  STRING      false
# 2661  quemAlimentaOsDadosNosSistemasDaRedeSUAS-prote...  STRING       true
# 2662  quemAlimentaOsDadosNosSistemasDaRedeSUAS-prote...  STRING      false
# 2663  quemAlimentaOsDadosNosSistemasDaRedeSUAS-prote...  STRING      false
# 2664  quemAlimentaOsDadosNosSistemasDaRedeSUAS-prote...  STRING       true
#
# [106600 rows x 6 columns]

# %% [markdown]
# ### E.8 Equipe que compõem setor de VS

# %%
EQUIPE_VS
# Out:
# ({'prefixo': 'qualEquipeCompoeOSetorDaVigilanciaSocioassistencial',
#   'suf_nome': 'nome'},
#  {'prefixo': 'qualEquipeCompoeOSetorDaVigilanciaSocioassistencial',
#   'suf_escolaridade': 'escolaridade'},
#  {'prefixo': 'qualEquipeCompoeOSetorDaVigilanciaSocioassistencial',
#   'suf_formacao': 'formacao'},
#  {'prefixo': 'qualEquipeCompoeOSetorDaVigilanciaSocioassistencial',
#   'suf_cargo': 'cargo'})

# %%
# Equipe do Setor de VS
colunas = ['protocolo', 'dt_protocolo', 'servico']

for i in EQUIPE_VS:
    print(i)
# Out:
# {'prefixo': 'qualEquipeCompoeOSetorDaVigilanciaSocioassistencial', 'suf_nome': 'nome'}
# {'prefixo': 'qualEquipeCompoeOSetorDaVigilanciaSocioassistencial', 'suf_escolaridade': 'escolaridade'}
# {'prefixo': 'qualEquipeCompoeOSetorDaVigilanciaSocioassistencial', 'suf_formacao': 'formacao'}
# {'prefixo': 'qualEquipeCompoeOSetorDaVigilanciaSocioassistencial', 'suf_cargo': 'cargo'}

# %%
# estipula a quantidade de profissionais que vão compor a equipe do setor de VS
n = rd.randint(N_EQUIPE_VS[0], N_EQUIPE_VS[1])
lst_tudo = []
# monta a estrutura de profissionais e seus atributos
for i in range(n):
    lst_linha = []
    lst_linha.append(names.get_full_name())
    lst_linha.append(rd.sample(lst_escolaridade, k=1)[0][0])
    lst_linha.append(rd.sample(lst_formacao, k=1)[0][0])
    lst_linha.append(rd.sample(lst_cargo, k=1)[0][0])
    lst_linha.append(rd.randint(1, 8))
    
    lst_tudo.append(lst_linha)

# %% [markdown]
# ### E.9 Capacitações Ofertadas

# %%
dff = df_final.copy()

# %%
# para cada protocolo e para cada atributo estipula as colunas
lst_co = []
for i in lst_pct_mu:
    for k in CAPACITACOES_OFERTADAS:
        atributo = k
        tipo = 'INTEGER'
        valor = rd.randint(N_CAPACITACOES_OFERTADAS[0], N_CAPACITACOES_OFERTADAS[1])
        lst_co.append([i, atributo, tipo, valor])

df_tmp = pd.DataFrame(lst_co, columns=['protocolo', 'atributo', 'tipo', 'valor'])
df_tmp = pd.merge(df_pct_mu, df_tmp).drop(['idx', 'municipio'], axis=1)

dff = pd.concat([df_final, df_tmp])
dff
# Out:
#          protocolo dt_protocolo                 servico  \
# 0          pct_m_1   2018-07-01  o1-semestral municipio
# 1          pct_m_1   2018-07-01  o1-semestral municipio
# 2          pct_m_1   2018-07-01  o1-semestral municipio
# 3          pct_m_1   2018-07-01  o1-semestral municipio
# 4          pct_m_1   2018-07-01  o1-semestral municipio
# ...            ...          ...                     ...
# 127915  pct_m_2665   2021-07-02  o1-semestral municipio
# 127916  pct_m_2665   2021-07-02  o1-semestral municipio
# 127917  pct_m_2665   2021-07-02  o1-semestral municipio
# 127918  pct_m_2665   2021-07-02  o1-semestral municipio
# 127919  pct_m_2665   2021-07-02  o1-semestral municipio
#
#                                                  atributo     tipo      valor
# 0                                                   col_1   STRING  valor_440
# 1                                                   col_2   STRING  valor_651
# 2                                                   col_3   STRING  valor_936
# 3                                                   col_4   STRING   valor_40
# 4                                                   col_5   STRING  valor_272
# ...                                                   ...      ...        ...
# 127915  capacitacoesOfertadasProtecaoSocialEspecial-tr...  INTEGER         15
# 127916  capacitacoesOfertadasProtecaoSocialEspecial-tr...  INTEGER         15
# 127917  capacitacoesOfertadasProtecaoSocialEspecial-tr...  INTEGER         51
# 127918  capacitacoesOfertadasProtecaoSocialEspecial-tr...  INTEGER         60
# 127919  capacitacoesOfertadasProtecaoSocialEspecial-tr...  INTEGER         67
#
# [234520 rows x 6 columns]

# %%
lst_co
# Out:
# [['pct_m_1',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeEstado',
#   'INTEGER',
#   61],
#  ['pct_m_1',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   96],
#  ['pct_m_1',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   35],
#  ['pct_m_1',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
#   'INTEGER',
#   12],
#  ['pct_m_1',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   63],
#  ['pct_m_1',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#   'INTEGER',
#   11],
#  ['pct_m_1',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   14],
#  ['pct_m_1',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   33],
#  ['pct_m_1',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   65],
#  ['pct_m_1',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   21],
#  ['pct_m_1',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   33],
#  ['pct_m_1',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   26],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
#   'INTEGER',
#   12],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   100],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   9],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
#   'INTEGER',
#   57],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   95],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#   'INTEGER',
#   80],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   6],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   12],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   88],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   44],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   26],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   49],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   4],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   53],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   77],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeEstado',
#   'INTEGER',
#   60],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   67],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   71],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   41],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   52],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   92],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   11],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   39],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   90],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   81],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   75],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   4],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeEstado',
#   'INTEGER',
#   67],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   48],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   4],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   69],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   73],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   79],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   55],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   11],
#  ['pct_m_1',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   71],
#  ['pct_m_2',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeEstado',
#   'INTEGER',
#   92],
#  ['pct_m_2',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   60],
#  ['pct_m_2',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   40],
#  ['pct_m_2',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
#   'INTEGER',
#   97],
#  ['pct_m_2',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   78],
#  ['pct_m_2',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#   'INTEGER',
#   85],
#  ['pct_m_2',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   13],
#  ['pct_m_2',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   93],
#  ['pct_m_2',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   67],
#  ['pct_m_2',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   40],
#  ['pct_m_2',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   54],
#  ['pct_m_2',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   32],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
#   'INTEGER',
#   48],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   45],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   43],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
#   'INTEGER',
#   79],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   62],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#   'INTEGER',
#   34],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   28],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   61],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   17],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   54],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   41],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   41],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   35],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   41],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   61],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeEstado',
#   'INTEGER',
#   94],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   41],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   2],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   40],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   59],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   7],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   27],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   31],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   86],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   57],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   67],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   85],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeEstado',
#   'INTEGER',
#   11],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   41],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   30],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   43],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   29],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   82],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   40],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   15],
#  ['pct_m_2',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   54],
#  ['pct_m_3',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeEstado',
#   'INTEGER',
#   14],
#  ['pct_m_3',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   29],
#  ['pct_m_3',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   75],
#  ['pct_m_3',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
#   'INTEGER',
#   66],
#  ['pct_m_3',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   16],
#  ['pct_m_3',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#   'INTEGER',
#   48],
#  ['pct_m_3',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   7],
#  ['pct_m_3',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   12],
#  ['pct_m_3',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   92],
#  ['pct_m_3',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   0],
#  ['pct_m_3',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   96],
#  ['pct_m_3',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   40],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
#   'INTEGER',
#   96],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   36],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   59],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
#   'INTEGER',
#   88],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   72],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#   'INTEGER',
#   49],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   97],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   34],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   60],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   96],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   72],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   14],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   85],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   25],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   76],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeEstado',
#   'INTEGER',
#   93],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   68],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   13],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   71],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   5],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   31],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   69],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   23],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   33],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   39],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   27],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   39],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeEstado',
#   'INTEGER',
#   76],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   95],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   84],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   6],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   28],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   9],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   12],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   20],
#  ['pct_m_3',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   81],
#  ['pct_m_4',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeEstado',
#   'INTEGER',
#   15],
#  ['pct_m_4',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   92],
#  ['pct_m_4',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   72],
#  ['pct_m_4',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
#   'INTEGER',
#   15],
#  ['pct_m_4',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   83],
#  ['pct_m_4',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#   'INTEGER',
#   92],
#  ['pct_m_4',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   4],
#  ['pct_m_4',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   58],
#  ['pct_m_4',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   26],
#  ['pct_m_4',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   95],
#  ['pct_m_4',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   5],
#  ['pct_m_4',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   57],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
#   'INTEGER',
#   33],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   60],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   27],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
#   'INTEGER',
#   39],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   92],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#   'INTEGER',
#   63],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   19],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   100],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   77],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   85],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   92],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   8],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   54],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   9],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   60],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeEstado',
#   'INTEGER',
#   5],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   75],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   100],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   32],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   29],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   14],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   73],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   25],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   36],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   25],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   27],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   58],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeEstado',
#   'INTEGER',
#   71],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   18],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   11],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   42],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   5],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   31],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   91],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   85],
#  ['pct_m_4',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   26],
#  ['pct_m_5',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeEstado',
#   'INTEGER',
#   5],
#  ['pct_m_5',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   86],
#  ['pct_m_5',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   18],
#  ['pct_m_5',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
#   'INTEGER',
#   73],
#  ['pct_m_5',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   30],
#  ['pct_m_5',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#   'INTEGER',
#   32],
#  ['pct_m_5',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   31],
#  ['pct_m_5',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   7],
#  ['pct_m_5',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   98],
#  ['pct_m_5',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   99],
#  ['pct_m_5',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   97],
#  ['pct_m_5',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   3],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
#   'INTEGER',
#   87],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   34],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   12],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
#   'INTEGER',
#   66],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   47],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#   'INTEGER',
#   69],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   77],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   0],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   2],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   17],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   52],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   46],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   82],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   80],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   75],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeEstado',
#   'INTEGER',
#   29],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   5],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   26],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   81],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   93],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   96],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   50],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   12],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   30],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   4],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   5],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   93],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeEstado',
#   'INTEGER',
#   47],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   93],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   35],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   1],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   72],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   89],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   1],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   88],
#  ['pct_m_5',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   94],
#  ['pct_m_6',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeEstado',
#   'INTEGER',
#   71],
#  ['pct_m_6',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   80],
#  ['pct_m_6',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   28],
#  ['pct_m_6',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
#   'INTEGER',
#   78],
#  ['pct_m_6',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   67],
#  ['pct_m_6',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#   'INTEGER',
#   42],
#  ['pct_m_6',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   34],
#  ['pct_m_6',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   51],
#  ['pct_m_6',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   93],
#  ['pct_m_6',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   33],
#  ['pct_m_6',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   0],
#  ['pct_m_6',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   15],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
#   'INTEGER',
#   61],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   70],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   100],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
#   'INTEGER',
#   60],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   36],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#   'INTEGER',
#   24],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   85],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   100],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   33],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   93],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   56],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   23],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   89],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   19],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   55],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeEstado',
#   'INTEGER',
#   3],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   86],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   99],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   89],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   7],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   61],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   61],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   80],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   45],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   66],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   87],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   30],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeEstado',
#   'INTEGER',
#   11],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   68],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   34],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   37],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   73],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   82],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   10],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   3],
#  ['pct_m_6',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   10],
#  ['pct_m_7',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeEstado',
#   'INTEGER',
#   74],
#  ['pct_m_7',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   50],
#  ['pct_m_7',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   49],
#  ['pct_m_7',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
#   'INTEGER',
#   15],
#  ['pct_m_7',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   27],
#  ['pct_m_7',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#   'INTEGER',
#   84],
#  ['pct_m_7',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   29],
#  ['pct_m_7',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   95],
#  ['pct_m_7',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   17],
#  ['pct_m_7',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   20],
#  ['pct_m_7',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   5],
#  ['pct_m_7',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   74],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
#   'INTEGER',
#   56],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   13],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   7],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
#   'INTEGER',
#   35],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   61],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#   'INTEGER',
#   70],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   83],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   82],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   23],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   96],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   16],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   18],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   71],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   52],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   53],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeEstado',
#   'INTEGER',
#   25],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   3],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   43],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   0],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   18],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   46],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   18],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   95],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   44],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   32],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   8],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   97],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeEstado',
#   'INTEGER',
#   98],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   26],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   72],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   60],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   76],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   95],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   20],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   73],
#  ['pct_m_7',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   59],
#  ['pct_m_8',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeEstado',
#   'INTEGER',
#   57],
#  ['pct_m_8',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   14],
#  ['pct_m_8',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   80],
#  ['pct_m_8',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
#   'INTEGER',
#   87],
#  ['pct_m_8',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   17],
#  ['pct_m_8',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#   'INTEGER',
#   61],
#  ['pct_m_8',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   90],
#  ['pct_m_8',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   65],
#  ['pct_m_8',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   47],
#  ['pct_m_8',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   100],
#  ['pct_m_8',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   95],
#  ['pct_m_8',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   54],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
#   'INTEGER',
#   75],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   53],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   78],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
#   'INTEGER',
#   25],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   99],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#   'INTEGER',
#   98],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   72],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   97],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   6],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   44],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   71],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   32],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   59],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   88],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   76],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeEstado',
#   'INTEGER',
#   6],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   27],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   21],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   81],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   25],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   44],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   37],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   87],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   6],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   87],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   52],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   52],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeEstado',
#   'INTEGER',
#   21],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   67],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   52],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   81],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   88],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   84],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   18],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   36],
#  ['pct_m_8',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   62],
#  ['pct_m_9',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeEstado',
#   'INTEGER',
#   25],
#  ['pct_m_9',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   93],
#  ['pct_m_9',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   93],
#  ['pct_m_9',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
#   'INTEGER',
#   18],
#  ['pct_m_9',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   46],
#  ['pct_m_9',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#   'INTEGER',
#   20],
#  ['pct_m_9',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   41],
#  ['pct_m_9',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   16],
#  ['pct_m_9',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   53],
#  ['pct_m_9',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   0],
#  ['pct_m_9',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   46],
#  ['pct_m_9',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   72],
#  ['pct_m_9',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
#   'INTEGER',
#   48],
#  ['pct_m_9',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   35],
#  ['pct_m_9',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   24],
#  ['pct_m_9',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
#   'INTEGER',
#   75],
#  ['pct_m_9',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   65],
#  ['pct_m_9',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#   'INTEGER',
#   6],
#  ['pct_m_9',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   92],
#  ['pct_m_9',
# ...
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
#   'INTEGER',
#   26],
#  ['pct_m_19',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   37],
#  ['pct_m_19',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#   'INTEGER',
#   18],
#  ['pct_m_19',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   31],
#  ['pct_m_19',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   79],
#  ['pct_m_19',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   97],
#  ['pct_m_19',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   53],
#  ['pct_m_19',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   10],
#  ['pct_m_19',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   20],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
#   'INTEGER',
#   7],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   88],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   8],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
#   'INTEGER',
#   45],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   75],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#   'INTEGER',
#   42],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   66],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   74],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   91],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   69],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   85],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   37],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   79],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   79],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   64],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeEstado',
#   'INTEGER',
#   83],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   55],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   37],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   47],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   6],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   72],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   36],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   64],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   59],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   97],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   4],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   99],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeEstado',
#   'INTEGER',
#   83],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   84],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   55],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   48],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   60],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   92],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   46],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   87],
#  ['pct_m_19',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   58],
#  ['pct_m_20',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeEstado',
#   'INTEGER',
#   69],
#  ['pct_m_20',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   23],
#  ['pct_m_20',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   41],
#  ['pct_m_20',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
#   'INTEGER',
#   94],
#  ['pct_m_20',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   73],
#  ['pct_m_20',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#   'INTEGER',
#   55],
#  ['pct_m_20',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   83],
#  ['pct_m_20',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   68],
#  ['pct_m_20',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   18],
#  ['pct_m_20',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   47],
#  ['pct_m_20',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   66],
#  ['pct_m_20',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   72],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
#   'INTEGER',
#   0],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   74],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   97],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
#   'INTEGER',
#   96],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   99],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#   'INTEGER',
#   17],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   55],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   28],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   9],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   30],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   67],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   12],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   18],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   99],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   12],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeEstado',
#   'INTEGER',
#   35],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   29],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   78],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   62],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   73],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   63],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   50],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   52],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   96],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   51],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   39],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   44],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeEstado',
#   'INTEGER',
#   89],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   76],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   1],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   29],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   25],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   77],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   20],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   68],
#  ['pct_m_20',
#   'capacitacoesOfertadasProtecaoSocialEspecial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   66],
#  ['pct_m_21',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeEstado',
#   'INTEGER',
#   74],
#  ['pct_m_21',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   72],
#  ['pct_m_21',
#   'capacitacoesOfertadasGestaoSUAS-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   20],
#  ['pct_m_21',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeEstado',
#   'INTEGER',
#   16],
#  ['pct_m_21',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   78],
#  ['pct_m_21',
#   'capacitacoesOfertadasGestaoSUAS-gestor-quantidadeMunicipio',
#   'INTEGER',
#   21],
#  ['pct_m_21',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   85],
#  ['pct_m_21',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   17],
#  ['pct_m_21',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   17],
#  ['pct_m_21',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   5],
#  ['pct_m_21',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   38],
#  ['pct_m_21',
#   'capacitacoesOfertadasGestaoSUAS-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   49],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeEstado',
#   'INTEGER',
#   96],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   65],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialBasica-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   13],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeEstado',
#   'INTEGER',
#   91],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   9],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialBasica-gestor-quantidadeMunicipio',
#   'INTEGER',
#   62],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   27],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   56],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   75],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   38],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   40],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialBasica-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   63],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   20],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   84],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   94],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeEstado',
#   'INTEGER',
#   81],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeGovernoFederal',
#   'INTEGER',
#   68],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-gestor-quantidadeMunicipio',
#   'INTEGER',
#   46],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeEstado',
#   'INTEGER',
#   54],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeGovernoFederal',
#   'INTEGER',
#   37],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelMedio-quantidadeMunicipio',
#   'INTEGER',
#   48],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeEstado',
#   'INTEGER',
#   79],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeGovernoFederal',
#   'INTEGER',
#   72],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialControleSocial-trabalhadoresDeNivelSuperior-quantidadeMunicipio',
#   'INTEGER',
#   42],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeEstado',
#   'INTEGER',
#   58],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeGovernoFederal',
#   'INTEGER',
#   45],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialEspecial-conselheiros-quantidadeMunicipio',
#   'INTEGER',
#   42],
#  ['pct_m_21',
#   'capacitacoesOfertadasProtecaoSocialEspecial-gestor-quantidadeEstado',
#   'INTEGER',
#   25],
#  ...]

# %%
lst_pct_mu
# Out:
# ['pct_m_1',
#  'pct_m_2',
#  'pct_m_3',
#  'pct_m_4',
#  'pct_m_5',
#  'pct_m_6',
#  'pct_m_7',
#  'pct_m_8',
#  'pct_m_9',
#  'pct_m_10',
#  'pct_m_11',
#  'pct_m_12',
#  'pct_m_13',
#  'pct_m_14',
#  'pct_m_15',
#  'pct_m_16',
#  'pct_m_17',
#  'pct_m_18',
#  'pct_m_19',
#  'pct_m_20',
#  'pct_m_21',
#  'pct_m_22',
#  'pct_m_23',
#  'pct_m_24',
#  'pct_m_25',
#  'pct_m_26',
#  'pct_m_27',
#  'pct_m_28',
#  'pct_m_29',
#  'pct_m_30',
#  'pct_m_31',
#  'pct_m_32',
#  'pct_m_33',
#  'pct_m_34',
#  'pct_m_35',
#  'pct_m_36',
#  'pct_m_37',
#  'pct_m_38',
#  'pct_m_39',
#  'pct_m_40',
#  'pct_m_41',
#  'pct_m_42',
#  'pct_m_43',
#  'pct_m_44',
#  'pct_m_45',
#  'pct_m_46',
#  'pct_m_47',
#  'pct_m_48',
#  'pct_m_49',
#  'pct_m_50',
#  'pct_m_51',
#  'pct_m_52',
#  'pct_m_53',
#  'pct_m_54',
#  'pct_m_55',
#  'pct_m_56',
#  'pct_m_57',
#  'pct_m_58',
#  'pct_m_59',
#  'pct_m_60',
#  'pct_m_61',
#  'pct_m_62',
#  'pct_m_63',
#  'pct_m_64',
#  'pct_m_65',
#  'pct_m_66',
#  'pct_m_67',
#  'pct_m_68',
#  'pct_m_69',
#  'pct_m_70',
#  'pct_m_71',
#  'pct_m_72',
#  'pct_m_73',
#  'pct_m_74',
#  'pct_m_75',
#  'pct_m_76',
#  'pct_m_77',
#  'pct_m_78',
#  'pct_m_79',
#  'pct_m_80',
#  'pct_m_81',
#  'pct_m_82',
#  'pct_m_83',
#  'pct_m_84',
#  'pct_m_85',
#  'pct_m_86',
#  'pct_m_87',
#  'pct_m_88',
#  'pct_m_89',
#  'pct_m_90',
#  'pct_m_91',
#  'pct_m_92',
#  'pct_m_93',
#  'pct_m_94',
#  'pct_m_95',
#  'pct_m_96',
#  'pct_m_97',
#  'pct_m_98',
#  'pct_m_99',
#  'pct_m_100',
#  'pct_m_101',
#  'pct_m_102',
#  'pct_m_103',
#  'pct_m_104',
#  'pct_m_105',
#  'pct_m_106',
#  'pct_m_107',
#  'pct_m_108',
#  'pct_m_109',
#  'pct_m_110',
#  'pct_m_111',
#  'pct_m_112',
#  'pct_m_113',
#  'pct_m_114',
#  'pct_m_115',
#  'pct_m_116',
#  'pct_m_117',
#  'pct_m_118',
#  'pct_m_119',
#  'pct_m_120',
#  'pct_m_121',
#  'pct_m_122',
#  'pct_m_123',
#  'pct_m_124',
#  'pct_m_125',
#  'pct_m_126',
#  'pct_m_127',
#  'pct_m_128',
#  'pct_m_129',
#  'pct_m_130',
#  'pct_m_131',
#  'pct_m_132',
#  'pct_m_133',
#  'pct_m_134',
#  'pct_m_135',
#  'pct_m_136',
#  'pct_m_137',
#  'pct_m_138',
#  'pct_m_139',
#  'pct_m_140',
#  'pct_m_141',
#  'pct_m_142',
#  'pct_m_143',
#  'pct_m_144',
#  'pct_m_145',
#  'pct_m_146',
#  'pct_m_147',
#  'pct_m_148',
#  'pct_m_149',
#  'pct_m_150',
#  'pct_m_151',
#  'pct_m_152',
#  'pct_m_153',
#  'pct_m_154',
#  'pct_m_155',
#  'pct_m_156',
#  'pct_m_157',
#  'pct_m_158',
#  'pct_m_159',
#  'pct_m_160',
#  'pct_m_161',
#  'pct_m_162',
#  'pct_m_163',
#  'pct_m_164',
#  'pct_m_165',
#  'pct_m_166',
#  'pct_m_167',
#  'pct_m_168',
#  'pct_m_169',
#  'pct_m_170',
#  'pct_m_171',
#  'pct_m_172',
#  'pct_m_173',
#  'pct_m_174',
#  'pct_m_175',
#  'pct_m_176',
#  'pct_m_177',
#  'pct_m_178',
#  'pct_m_179',
#  'pct_m_180',
#  'pct_m_181',
#  'pct_m_182',
#  'pct_m_183',
#  'pct_m_184',
#  'pct_m_185',
#  'pct_m_186',
#  'pct_m_187',
#  'pct_m_188',
#  'pct_m_189',
#  'pct_m_190',
#  'pct_m_191',
#  'pct_m_192',
#  'pct_m_193',
#  'pct_m_194',
#  'pct_m_195',
#  'pct_m_196',
#  'pct_m_197',
#  'pct_m_198',
#  'pct_m_199',
#  'pct_m_200',
#  'pct_m_201',
#  'pct_m_202',
#  'pct_m_203',
#  'pct_m_204',
#  'pct_m_205',
#  'pct_m_206',
#  'pct_m_207',
#  'pct_m_208',
#  'pct_m_209',
#  'pct_m_210',
#  'pct_m_211',
#  'pct_m_212',
#  'pct_m_213',
#  'pct_m_214',
#  'pct_m_215',
#  'pct_m_216',
#  'pct_m_217',
#  'pct_m_218',
#  'pct_m_219',
#  'pct_m_220',
#  'pct_m_221',
#  'pct_m_222',
#  'pct_m_223',
#  'pct_m_224',
#  'pct_m_225',
#  'pct_m_226',
#  'pct_m_227',
#  'pct_m_228',
#  'pct_m_229',
#  'pct_m_230',
#  'pct_m_231',
#  'pct_m_232',
#  'pct_m_233',
#  'pct_m_234',
#  'pct_m_235',
#  'pct_m_236',
#  'pct_m_237',
#  'pct_m_238',
#  'pct_m_239',
#  'pct_m_240',
#  'pct_m_241',
#  'pct_m_242',
#  'pct_m_243',
#  'pct_m_244',
#  'pct_m_245',
#  'pct_m_246',
#  'pct_m_247',
#  'pct_m_248',
#  'pct_m_249',
#  'pct_m_250',
#  'pct_m_251',
#  'pct_m_252',
#  'pct_m_253',
#  'pct_m_254',
#  'pct_m_255',
#  'pct_m_256',
#  'pct_m_257',
#  'pct_m_258',
#  'pct_m_259',
#  'pct_m_260',
#  'pct_m_261',
#  'pct_m_262',
#  'pct_m_263',
#  'pct_m_264',
#  'pct_m_265',
#  'pct_m_266',
#  'pct_m_267',
#  'pct_m_268',
#  'pct_m_269',
#  'pct_m_270',
#  'pct_m_271',
#  'pct_m_272',
#  'pct_m_273',
#  'pct_m_274',
#  'pct_m_275',
#  'pct_m_276',
#  'pct_m_277',
#  'pct_m_278',
#  'pct_m_279',
#  'pct_m_280',
#  'pct_m_281',
#  'pct_m_282',
#  'pct_m_283',
#  'pct_m_284',
#  'pct_m_285',
#  'pct_m_286',
#  'pct_m_287',
#  'pct_m_288',
#  'pct_m_289',
#  'pct_m_290',
#  'pct_m_291',
#  'pct_m_292',
#  'pct_m_293',
#  'pct_m_294',
#  'pct_m_295',
#  'pct_m_296',
#  'pct_m_297',
#  'pct_m_298',
#  'pct_m_299',
#  'pct_m_300',
#  'pct_m_301',
#  'pct_m_302',
#  'pct_m_303',
#  'pct_m_304',
#  'pct_m_305',
#  'pct_m_306',
#  'pct_m_307',
#  'pct_m_308',
#  'pct_m_309',
#  'pct_m_310',
#  'pct_m_311',
#  'pct_m_312',
#  'pct_m_313',
#  'pct_m_314',
#  'pct_m_315',
#  'pct_m_316',
#  'pct_m_317',
#  'pct_m_318',
#  'pct_m_319',
#  'pct_m_320',
#  'pct_m_321',
#  'pct_m_322',
#  'pct_m_323',
#  'pct_m_324',
#  'pct_m_325',
#  'pct_m_326',
#  'pct_m_327',
#  'pct_m_328',
#  'pct_m_329',
#  'pct_m_330',
#  'pct_m_331',
#  'pct_m_332',
#  'pct_m_333',
#  'pct_m_334',
#  'pct_m_335',
#  'pct_m_336',
#  'pct_m_337',
#  'pct_m_338',
#  'pct_m_339',
#  'pct_m_340',
#  'pct_m_341',
#  'pct_m_342',
#  'pct_m_343',
#  'pct_m_344',
#  'pct_m_345',
#  'pct_m_346',
#  'pct_m_347',
#  'pct_m_348',
#  'pct_m_349',
#  'pct_m_350',
#  'pct_m_351',
#  'pct_m_352',
#  'pct_m_353',
#  'pct_m_354',
#  'pct_m_355',
#  'pct_m_356',
#  'pct_m_357',
#  'pct_m_358',
#  'pct_m_359',
#  'pct_m_360',
#  'pct_m_361',
#  'pct_m_362',
#  'pct_m_363',
#  'pct_m_364',
#  'pct_m_365',
#  'pct_m_366',
#  'pct_m_367',
#  'pct_m_368',
#  'pct_m_369',
#  'pct_m_370',
#  'pct_m_371',
#  'pct_m_372',
#  'pct_m_373',
#  'pct_m_374',
#  'pct_m_375',
#  'pct_m_376',
#  'pct_m_377',
#  'pct_m_378',
#  'pct_m_379',
#  'pct_m_380',
#  'pct_m_381',
#  'pct_m_382',
#  'pct_m_383',
#  'pct_m_384',
#  'pct_m_385',
#  'pct_m_386',
#  'pct_m_387',
#  'pct_m_388',
#  'pct_m_389',
#  'pct_m_390',
#  'pct_m_391',
#  'pct_m_392',
#  'pct_m_393',
#  'pct_m_394',
#  'pct_m_395',
#  'pct_m_396',
#  'pct_m_397',
#  'pct_m_398',
#  'pct_m_399',
#  'pct_m_400',
#  'pct_m_401',
#  'pct_m_402',
#  'pct_m_403',
#  'pct_m_404',
#  'pct_m_405',
#  'pct_m_406',
#  'pct_m_407',
#  'pct_m_408',
#  'pct_m_409',
#  'pct_m_410',
#  'pct_m_411',
#  'pct_m_412',
#  'pct_m_413',
#  'pct_m_414',
#  'pct_m_415',
#  'pct_m_416',
#  'pct_m_417',
#  'pct_m_418',
#  'pct_m_419',
#  'pct_m_420',
#  'pct_m_421',
#  'pct_m_422',
#  'pct_m_423',
#  'pct_m_424',
#  'pct_m_425',
#  'pct_m_426',
#  'pct_m_427',
#  'pct_m_428',
#  'pct_m_429',
#  'pct_m_430',
#  'pct_m_431',
#  'pct_m_432',
#  'pct_m_433',
#  'pct_m_434',
#  'pct_m_435',
#  'pct_m_436',
#  'pct_m_437',
#  'pct_m_438',
#  'pct_m_439',
#  'pct_m_440',
#  'pct_m_441',
#  'pct_m_442',
#  'pct_m_443',
#  'pct_m_444',
#  'pct_m_445',
#  'pct_m_446',
#  'pct_m_447',
#  'pct_m_448',
#  'pct_m_449',
#  'pct_m_450',
#  'pct_m_451',
#  'pct_m_452',
#  'pct_m_453',
#  'pct_m_454',
#  'pct_m_455',
#  'pct_m_456',
#  'pct_m_457',
#  'pct_m_458',
#  'pct_m_459',
#  'pct_m_460',
#  'pct_m_461',
#  'pct_m_462',
#  'pct_m_463',
#  'pct_m_464',
#  'pct_m_465',
#  'pct_m_466',
#  'pct_m_467',
#  'pct_m_468',
#  'pct_m_469',
#  'pct_m_470',
#  'pct_m_471',
#  'pct_m_472',
#  'pct_m_473',
#  'pct_m_474',
#  'pct_m_475',
#  'pct_m_476',
#  'pct_m_477',
#  'pct_m_478',
#  'pct_m_479',
#  'pct_m_480',
#  'pct_m_481',
#  'pct_m_482',
#  'pct_m_483',
#  'pct_m_484',
#  'pct_m_485',
#  'pct_m_486',
#  'pct_m_487',
#  'pct_m_488',
#  'pct_m_489',
#  'pct_m_490',
#  'pct_m_491',
#  'pct_m_492',
#  'pct_m_493',
#  'pct_m_494',
#  'pct_m_495',
#  'pct_m_496',
#  'pct_m_497',
#  'pct_m_498',
#  'pct_m_499',
#  'pct_m_500',
#  'pct_m_501',
#  'pct_m_502',
#  'pct_m_503',
#  'pct_m_504',
#  'pct_m_505',
#  'pct_m_506',
#  'pct_m_507',
#  'pct_m_508',
#  'pct_m_509',
#  'pct_m_510',
#  'pct_m_511',
#  'pct_m_512',
#  'pct_m_513',
#  'pct_m_514',
#  'pct_m_515',
#  'pct_m_516',
#  'pct_m_517',
#  'pct_m_518',
#  'pct_m_519',
#  'pct_m_520',
#  'pct_m_521',
#  'pct_m_522',
#  'pct_m_523',
#  'pct_m_524',
#  'pct_m_525',
#  'pct_m_526',
#  'pct_m_527',
#  'pct_m_528',
#  'pct_m_529',
#  'pct_m_530',
#  'pct_m_531',
#  'pct_m_532',
#  'pct_m_533',
#  'pct_m_534',
#  'pct_m_535',
#  'pct_m_536',
#  'pct_m_537',
#  'pct_m_538',
#  'pct_m_539',
#  'pct_m_540',
#  'pct_m_541',
#  'pct_m_542',
#  'pct_m_543',
#  'pct_m_544',
#  'pct_m_545',
#  'pct_m_546',
#  'pct_m_547',
#  'pct_m_548',
#  'pct_m_549',
#  'pct_m_550',
#  'pct_m_551',
#  'pct_m_552',
#  'pct_m_553',
#  'pct_m_554',
#  'pct_m_555',
#  'pct_m_556',
#  'pct_m_557',
#  'pct_m_558',
#  'pct_m_559',
#  'pct_m_560',
#  'pct_m_561',
#  'pct_m_562',
#  'pct_m_563',
#  'pct_m_564',
#  'pct_m_565',
#  'pct_m_566',
#  'pct_m_567',
#  'pct_m_568',
#  'pct_m_569',
#  'pct_m_570',
#  'pct_m_571',
#  'pct_m_572',
#  'pct_m_573',
#  'pct_m_574',
#  'pct_m_575',
#  'pct_m_576',
#  'pct_m_577',
#  'pct_m_578',
#  'pct_m_579',
#  'pct_m_580',
#  'pct_m_581',
#  'pct_m_582',
#  'pct_m_583',
#  'pct_m_584',
#  'pct_m_585',
#  'pct_m_586',
#  'pct_m_587',
#  'pct_m_588',
#  'pct_m_589',
#  'pct_m_590',
#  'pct_m_591',
#  'pct_m_592',
#  'pct_m_593',
#  'pct_m_594',
#  'pct_m_595',
#  'pct_m_596',
#  'pct_m_597',
#  'pct_m_598',
#  'pct_m_599',
#  'pct_m_600',
#  'pct_m_601',
#  'pct_m_602',
#  'pct_m_603',
#  'pct_m_604',
#  'pct_m_605',
#  'pct_m_606',
#  'pct_m_607',
#  'pct_m_608',
#  'pct_m_609',
#  'pct_m_610',
#  'pct_m_611',
#  'pct_m_612',
#  'pct_m_613',
#  'pct_m_614',
#  'pct_m_615',
#  'pct_m_616',
#  'pct_m_617',
#  'pct_m_618',
#  'pct_m_619',
#  'pct_m_620',
#  'pct_m_621',
#  'pct_m_622',
#  'pct_m_623',
#  'pct_m_624',
#  'pct_m_625',
#  'pct_m_626',
#  'pct_m_627',
#  'pct_m_628',
#  'pct_m_629',
#  'pct_m_630',
#  'pct_m_631',
#  'pct_m_632',
#  'pct_m_633',
#  'pct_m_634',
#  'pct_m_635',
#  'pct_m_636',
#  'pct_m_637',
#  'pct_m_638',
#  'pct_m_639',
#  'pct_m_640',
#  'pct_m_641',
#  'pct_m_642',
#  'pct_m_643',
#  'pct_m_644',
#  'pct_m_645',
#  'pct_m_646',
#  'pct_m_647',
#  'pct_m_648',
#  'pct_m_649',
#  'pct_m_650',
#  'pct_m_651',
#  'pct_m_652',
#  'pct_m_653',
#  'pct_m_654',
#  'pct_m_655',
#  'pct_m_656',
#  'pct_m_657',
#  'pct_m_658',
#  'pct_m_659',
#  'pct_m_660',
#  'pct_m_661',
#  'pct_m_662',
#  'pct_m_663',
#  'pct_m_664',
#  'pct_m_665',
#  'pct_m_666',
#  'pct_m_667',
#  'pct_m_668',
#  'pct_m_669',
#  'pct_m_670',
#  'pct_m_671',
#  'pct_m_672',
#  'pct_m_673',
#  'pct_m_674',
#  'pct_m_675',
#  'pct_m_676',
#  'pct_m_677',
#  'pct_m_678',
#  'pct_m_679',
#  'pct_m_680',
#  'pct_m_681',
#  'pct_m_682',
#  'pct_m_683',
#  'pct_m_684',
#  'pct_m_685',
#  'pct_m_686',
#  'pct_m_687',
#  'pct_m_688',
#  'pct_m_689',
#  'pct_m_690',
#  'pct_m_691',
#  'pct_m_692',
#  'pct_m_693',
#  'pct_m_694',
#  'pct_m_695',
#  'pct_m_696',
#  'pct_m_697',
#  'pct_m_698',
#  'pct_m_699',
#  'pct_m_700',
#  'pct_m_701',
#  'pct_m_702',
#  'pct_m_703',
#  'pct_m_704',
#  'pct_m_705',
#  'pct_m_706',
#  'pct_m_707',
#  'pct_m_708',
#  'pct_m_709',
#  'pct_m_710',
#  'pct_m_711',
#  'pct_m_712',
#  'pct_m_713',
#  'pct_m_714',
#  'pct_m_715',
#  'pct_m_716',
#  'pct_m_717',
#  'pct_m_718',
#  'pct_m_719',
#  'pct_m_720',
#  'pct_m_721',
#  'pct_m_722',
#  'pct_m_723',
#  'pct_m_724',
#  'pct_m_725',
#  'pct_m_726',
#  'pct_m_727',
#  'pct_m_728',
#  'pct_m_729',
#  'pct_m_730',
#  'pct_m_731',
#  'pct_m_732',
#  'pct_m_733',
#  'pct_m_734',
#  'pct_m_735',
#  'pct_m_736',
#  'pct_m_737',
#  'pct_m_738',
#  'pct_m_739',
#  'pct_m_740',
#  'pct_m_741',
#  'pct_m_742',
#  'pct_m_743',
#  'pct_m_744',
#  'pct_m_745',
#  'pct_m_746',
#  'pct_m_747',
#  'pct_m_748',
#  'pct_m_749',
#  'pct_m_750',
#  'pct_m_751',
#  'pct_m_752',
#  'pct_m_753',
#  'pct_m_754',
#  'pct_m_755',
#  'pct_m_756',
#  'pct_m_757',
#  'pct_m_758',
#  'pct_m_759',
#  'pct_m_760',
#  'pct_m_761',
#  'pct_m_762',
#  'pct_m_763',
#  'pct_m_764',
#  'pct_m_765',
#  'pct_m_766',
#  'pct_m_767',
#  'pct_m_768',
#  'pct_m_769',
#  'pct_m_770',
#  'pct_m_771',
#  'pct_m_772',
#  'pct_m_773',
#  'pct_m_774',
#  'pct_m_775',
#  'pct_m_776',
#  'pct_m_777',
#  'pct_m_778',
#  'pct_m_779',
#  'pct_m_780',
#  'pct_m_781',
#  'pct_m_782',
#  'pct_m_783',
#  'pct_m_784',
#  'pct_m_785',
#  'pct_m_786',
#  'pct_m_787',
#  'pct_m_788',
#  'pct_m_789',
#  'pct_m_790',
#  'pct_m_791',
#  'pct_m_792',
#  'pct_m_793',
#  'pct_m_794',
#  'pct_m_795',
#  'pct_m_796',
#  'pct_m_797',
#  'pct_m_798',
#  'pct_m_799',
#  'pct_m_800',
#  'pct_m_801',
#  'pct_m_802',
#  'pct_m_803',
#  'pct_m_804',
#  'pct_m_805',
#  'pct_m_806',
#  'pct_m_807',
#  'pct_m_808',
#  'pct_m_809',
#  'pct_m_810',
#  'pct_m_811',
#  'pct_m_812',
#  'pct_m_813',
#  'pct_m_814',
#  'pct_m_815',
#  'pct_m_816',
#  'pct_m_817',
#  'pct_m_818',
#  'pct_m_819',
#  'pct_m_820',
#  'pct_m_821',
#  'pct_m_822',
#  'pct_m_823',
#  'pct_m_824',
#  'pct_m_825',
#  'pct_m_826',
#  'pct_m_827',
#  'pct_m_828',
#  'pct_m_829',
#  'pct_m_830',
#  'pct_m_831',
#  'pct_m_832',
#  'pct_m_833',
#  'pct_m_834',
#  'pct_m_835',
#  'pct_m_836',
#  'pct_m_837',
#  'pct_m_838',
#  'pct_m_839',
#  'pct_m_840',
#  'pct_m_841',
#  'pct_m_842',
#  'pct_m_843',
#  'pct_m_844',
#  'pct_m_845',
#  'pct_m_846',
#  'pct_m_847',
#  'pct_m_848',
#  'pct_m_849',
#  'pct_m_850',
#  'pct_m_851',
#  'pct_m_852',
#  'pct_m_853',
#  'pct_m_854',
#  'pct_m_855',
#  'pct_m_856',
#  'pct_m_857',
#  'pct_m_858',
#  'pct_m_859',
#  'pct_m_860',
#  'pct_m_861',
#  'pct_m_862',
#  'pct_m_863',
#  'pct_m_864',
#  'pct_m_865',
#  'pct_m_866',
#  'pct_m_867',
#  'pct_m_868',
#  'pct_m_869',
#  'pct_m_870',
#  'pct_m_871',
#  'pct_m_872',
#  'pct_m_873',
#  'pct_m_874',
#  'pct_m_875',
#  'pct_m_876',
#  'pct_m_877',
#  'pct_m_878',
#  'pct_m_879',
#  'pct_m_880',
#  'pct_m_881',
#  'pct_m_882',
#  'pct_m_883',
#  'pct_m_884',
#  'pct_m_885',
#  'pct_m_886',
#  'pct_m_887',
#  'pct_m_888',
#  'pct_m_889',
#  'pct_m_890',
#  'pct_m_891',
#  'pct_m_892',
#  'pct_m_893',
#  'pct_m_894',
#  'pct_m_895',
#  'pct_m_896',
#  'pct_m_897',
#  'pct_m_898',
#  'pct_m_899',
#  'pct_m_900',
#  'pct_m_901',
#  'pct_m_902',
#  'pct_m_903',
#  'pct_m_904',
#  'pct_m_905',
#  'pct_m_906',
#  'pct_m_907',
#  'pct_m_908',
#  'pct_m_909',
#  'pct_m_910',
#  'pct_m_911',
#  'pct_m_912',
#  'pct_m_913',
#  'pct_m_914',
#  'pct_m_915',
#  'pct_m_916',
#  'pct_m_917',
#  'pct_m_918',
#  'pct_m_919',
#  'pct_m_920',
#  'pct_m_921',
#  'pct_m_922',
#  'pct_m_923',
#  'pct_m_924',
#  'pct_m_925',
#  'pct_m_926',
#  'pct_m_927',
#  'pct_m_928',
#  'pct_m_929',
#  'pct_m_930',
#  'pct_m_931',
#  'pct_m_932',
#  'pct_m_933',
#  'pct_m_934',
#  'pct_m_935',
#  'pct_m_936',
#  'pct_m_937',
#  'pct_m_938',
#  'pct_m_939',
#  'pct_m_940',
#  'pct_m_941',
#  'pct_m_942',
#  'pct_m_943',
#  'pct_m_944',
#  'pct_m_945',
#  'pct_m_946',
#  'pct_m_947',
#  'pct_m_948',
#  'pct_m_949',
#  'pct_m_950',
#  'pct_m_951',
#  'pct_m_952',
#  'pct_m_953',
#  'pct_m_954',
#  'pct_m_955',
#  'pct_m_956',
#  'pct_m_957',
#  'pct_m_958',
#  'pct_m_959',
#  'pct_m_960',
#  'pct_m_961',
#  'pct_m_962',
#  'pct_m_963',
#  'pct_m_964',
#  'pct_m_965',
#  'pct_m_966',
#  'pct_m_967',
#  'pct_m_968',
#  'pct_m_969',
#  'pct_m_970',
#  'pct_m_971',
#  'pct_m_972',
#  'pct_m_973',
#  'pct_m_974',
#  'pct_m_975',
#  'pct_m_976',
#  'pct_m_977',
#  'pct_m_978',
#  'pct_m_979',
#  'pct_m_980',
#  'pct_m_981',
#  'pct_m_982',
#  'pct_m_983',
#  'pct_m_984',
#  'pct_m_985',
#  'pct_m_986',
#  'pct_m_987',
#  'pct_m_988',
#  'pct_m_989',
#  'pct_m_990',
#  'pct_m_991',
#  'pct_m_992',
#  'pct_m_993',
#  'pct_m_994',
#  'pct_m_995',
#  'pct_m_996',
#  'pct_m_997',
#  'pct_m_998',
#  'pct_m_999',
#  'pct_m_1000',
#  ...]

# %% [markdown]
# ### E.10 Acompanhamento e assessoramento técnico estadual sobre o PAS

# %% [markdown]
# ### E.11 Atividades de Contrôle Social realizadas pelo Estado

# %% [markdown]
# # <font color='blue'>5.0 carga</font>

# %%
# grava tabelas
df_final.to_csv(caminho_out + 'dataset_sedes.csv', index=False)

# %% [markdown]
# # TESTES

# %%
import names

# %%
print(names.get_full_name())

print(names.get_full_name(gender='male'))

print(names.get_first_name())

print(names.get_first_name(gender='female'))

print(names.get_last_name())

# %%
for i in range(20):
    print(names.get_full_name())
